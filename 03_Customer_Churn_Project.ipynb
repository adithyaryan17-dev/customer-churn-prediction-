# %% [markdown]
# # Customer Churn Prediction in Retail Banking
#
# Professional Google Colab notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
# %matplotlib inline

# %% [markdown]
# ## Upload Dataset

# %%
uploaded=files.upload()
filename=list(uploaded.keys())[0]
df=pd.read_csv(filename)
df.head()

# %% [markdown]
# ## Data Understanding

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %% [markdown]
# ## Remove Non-Informative Columns

# %%
df=df.drop(["CustomerId","Surname"],axis=1)
df.head()

# %% [markdown]
# ## Initial EDA

# %%
sns.countplot(x="Exited",data=df);plt.show()

# %%
sns.histplot(df["Age"],kde=True);plt.show()

# %%
sns.countplot(x="Geography",hue="Exited",data=df);plt.show()

# %%
sns.countplot(x="Gender",hue="Exited",data=df);plt.show()

# %%
plt.figure(figsize=(10,8));sns.heatmap(df.select_dtypes(include=np.number).corr(),annot=True,cmap="coolwarm");plt.show()
